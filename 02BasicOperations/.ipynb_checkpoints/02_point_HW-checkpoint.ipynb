# %% [markdown]
# # Zadanie domowe
#
# W przypadku obrazów w odcieniach szarości pojedynczy piksel z zakresu [0; 255] reprezentowany jest jako 8-bitowa liczba bez znaku.
# Pewnym rozszerzeniem analizy sposobu reprezentacji obrazu może być następujący eksperyment.
# Załóżmy, że z każdego z 8 bitów możemy stworzyć pojedynczy obraz binarny (ang. _bit-plane slicing_).
# Dla obrazka _100zloty.jpg_ (https://raw.githubusercontent.com/vision-agh/poc_sw/master/02_Point/100zloty.jpg) stwórz 8 obrazów, z których każdy powinien zawierać jedną płaszczyznę bitową.
# Podpowiedź $-$ warto sprawdzić, jak realizuje się bitowe operacje logiczne.
# Zastosowanie takiej dekompozycji obrazu pozwala na analizę ,,ważności'' poszczególnych bitów.
# Jest to użyteczne w kwantyzacji, ale także w kompresji.
#
# W drugim etapie zadania proszę spróbować odtworzyć obraz oryginalny z mniejszej liczby obrazów binarnych.
# Warto zacząć od dwóch najbardziej znaczących bitów, a później dodawać kolejne.
# Należy utworzyć co najmniej trzy wersje zrekonstruowanych obrazów.
# Podpowiedź $-$ rekonstrukcja obrazu to mnożenie przez odpowiednią potęgę liczby 2 (przesunięcie bitowe) oraz dodawanie.

# %%
import cv2
import numpy as np
import os
import matplotlib.pyplot as plt

#Pobranie zdjecia
if not os.path.exists("100zloty.jpg") :
    # !wget https://raw.githubusercontent.com/vision-agh/poc_sw/master/02_Point/100zloty.jpg

#wczytwanie i przetworzenie na gray         
image = cv2.imread('100zloty.jpg') 
img = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
plt.gray()

#tworzenie 8 obrazów do analizy ważności poszczególnych bitów
c1= np.mod(img, 2);
c2= np.mod(np.floor(img/2), 2);
c3= np.mod(np.floor(img/4), 2);
c4= np.mod(np.floor(img/8), 2);
c5= np.mod(np.floor(img/16), 2);
c6= np.mod(np.floor(img/32), 2);
c7= np.mod(np.floor(img/64), 2);
c8= np.mod(np.floor(img/128), 2);

#wyśtwietlenie wyników 

f, ([ax1,ax2]) = plt.subplots(1,2)
ax1.imshow(c1)
ax1.title.set_text('bit-plane slicing for bit 1')
ax2.imshow(c2)
ax2.title.set_text('bit-plane slicing for bit 2')
f, ([ax3,ax4]) = plt.subplots(1,2)
ax3.imshow(c3)
ax3.title.set_text('bit-plane slicing for bit 3')
ax4.imshow(c4)
ax4.title.set_text('bit-plane slicing for bit 4')
f, ([ax5,ax6]) = plt.subplots(1,2)
ax5.imshow(c5)
ax5.title.set_text('bit-plane slicing for bit 5')
ax6.imshow(c6)
ax6.title.set_text('bit-plane slicing for bit 6')
f, ([ax7,ax8]) = plt.subplots(1,2)
ax7.imshow(c7)
ax7.title.set_text('bit-plane slicing for bit 7')
ax8.imshow(c8)
ax8.title.set_text('bit-plane slicing for bit 8')

#z tego wynika, że bardziej znaczące bity mają większą wartość liczbową, czyli zatem w większym stopniu mają wpływ na obrazek



#Rekonstrukcja obrazów
cc1 =(2 * c8 + c7);
cc2 = (2 * (2 * (2 * (2 * c8 + c7) + c6) + c5) + c4) ;
cc3 = (2 * (2 * (2 * (2 * (2 * c8 + c7) + c6) + c5) + c4) + c3);
cc4 = (2 * (2 * (2 * (2 * (2 * (2 * (2 * c8 + c7) + c6) + c5) + c4) + c3) + c2) + c1);

#wyświetlanie zrekonstrułowanych obrazów
f, (bx1,bx2) = plt.subplots(1,2)
bx1.imshow(cc1)
bx1.title.set_text('reconstruction 1')
bx2.imshow(cc2)
bx2.title.set_text('reconstruction 2')
f, (bx3,bx4) = plt.subplots(1,2)
bx3.imshow(cc3)
bx3.title.set_text('reconstruction 3')
bx4.imshow(cc4)
bx4.title.set_text('reconstruction 4')
